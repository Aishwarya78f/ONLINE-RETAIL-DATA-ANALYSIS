# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (0.22.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.10.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.24.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (3.6.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from mlxtend) (63.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\aishwarya shanker\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
df = pd.read_csv("Online-Retail-Dataset.csv", encoding = 'latin1')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  Price  Customer ID         Country
# 0  01-12-2010 08:26   2.55      17850.0  United Kingdom
# 1  01-12-2010 08:26   3.39      17850.0  United Kingdom
# 2  01-12-2010 08:26   2.75      17850.0  United Kingdom
# 3  01-12-2010 08:26   3.39      17850.0  United Kingdom
# 4  01-12-2010 08:26   3.39      17850.0  United Kingdom

# %%
df.shape
# Out:
# (541910, 8)

# %%
df.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity          Price    Customer ID
# count  541910.000000  541910.000000  406830.000000
# mean        9.552234       4.611138   15287.684160
# std       218.080957      96.759765    1713.603074
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis = 0, subset = ['Invoice'], inplace = True)
df['Invoice'] = df['Invoice'].astype('str')
df = df[~df['Invoice'].str.contains('C')]

# %%
df.shape
# Out:
# (532622, 8)

# %%
basket = (df[df['Country'] == "France"].groupby(['Invoice', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0).set_index('Invoice'))
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# Invoice
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# Invoice
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# Invoice
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# Invoice
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# Invoice
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# Invoice                                     ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# Invoice
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# Invoice
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# Invoice
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# Invoice
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
#
# [5 rows x 1563 columns]

# %%
basket.shape
# Out:
# (392, 1563)

# %%
 def encode_units(y):
    if y <= 0:
        return 0
    if y >= 1:
        return 1
    
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace = True, axis = 1)
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# Invoice
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# Invoice
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# Invoice
# 536370                                   0
# 536852                                   0
# 536974                                   0
# 537065                                   0
# 537463                                   0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# Invoice
# 536370                                         0                            0
# 536852                                         0                            0
# 536974                                         0                            0
# 537065                                         0                            0
# 537463                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# Invoice
# 536370                               0                                   0
# 536852                               0                                   0
# 536974                               0                                   0
# 537065                               0                                   0
# 537463                               0                                   0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# Invoice                                     ...
# 536370                                   0  ...                            0
# 536852                                   0  ...                            0
# 536974                                   0  ...                            0
# 537065                                   0  ...                            0
# 537463                                   0  ...                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# Invoice
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# Invoice
# 536370                             0                          0
# 536852                             0                          0
# 536974                             0                          0
# 537065                             0                          0
# 537463                             0                          0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# Invoice
# 536370                               0                           0
# 536852                               0                           0
# 536974                               0                           0
# 537065                               0                           0
# 537463                               0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# Invoice
# 536370                                     0
# 536852                                     0
# 536974                                     0
# 537065                                     0
# 537463                                     0
#
# [5 rows x 1562 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support = 0.07, use_colnames = True)

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(frequent_itemsets, metric = "lift", min_threshold = 1)
rules.head()
# Out:
#                     antecedents                   consequents  \
# 0  (ALARM CLOCK BAKELIKE GREEN)   (ALARM CLOCK BAKELIKE PINK)
# 1   (ALARM CLOCK BAKELIKE PINK)  (ALARM CLOCK BAKELIKE GREEN)
# 2  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)
# 3    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)
# 4    (ALARM CLOCK BAKELIKE RED)   (ALARM CLOCK BAKELIKE PINK)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.096939            0.102041  0.073980    0.763158  7.478947
# 1            0.102041            0.096939  0.073980    0.725000  7.478947
# 2            0.096939            0.094388  0.079082    0.815789  8.642959
# 3            0.094388            0.096939  0.079082    0.837838  8.642959
# 4            0.094388            0.102041  0.073980    0.783784  7.681081
#
#    leverage  conviction  zhangs_metric
# 0  0.064088    3.791383       0.959283
# 1  0.064088    3.283859       0.964734
# 2  0.069932    4.916181       0.979224
# 3  0.069932    5.568878       0.976465
# 4  0.064348    4.153061       0.960466

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x = "support", y = "confidence", size = "lift", data = rules)
plt.show()

# %%
rules[(rules['lift'] >= 6) & (rules['confidence'] >= 0.8)]
# Out:
#                                           antecedents  \
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 16                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                    (SET/6 RED SPOTTY PAPER PLATES)
# 19                      (SET/6 RED SPOTTY PAPER CUPS)
# 20  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 21  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 22  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
#
#                              consequents  antecedent support  \
# 2             (ALARM CLOCK BAKELIKE RED)            0.096939
# 3           (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 16  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 18         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 19       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 20         (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 22       (SET/6 RED SPOTTY PAPER PLATES)            0.102041
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 2             0.094388  0.079082    0.815789  8.642959  0.069932    4.916181
# 3             0.096939  0.079082    0.837838  8.642959  0.069932    5.568878
# 16            0.132653  0.102041    0.800000  6.030769  0.085121    4.336735
# 18            0.137755  0.122449    0.960000  6.968889  0.104878   21.556122
# 19            0.127551  0.122449    0.888889  6.968889  0.104878    7.852041
# 20            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# 21            0.132653  0.099490    0.812500  6.125000  0.083247    4.625850
# 22            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
#
#     zhangs_metric
# 2        0.979224
# 3        0.976465
# 16       0.956140
# 18       0.981725
# 19       0.993343
# 20       0.956294
# 21       0.953488
# 22       0.967949

# %%
print("ALARM CLOCK BAKELIKE GREEN : ", basket['ALARM CLOCK BAKELIKE GREEN'].sum())
print("ALARM CLOCK BAKELIKE RED   : ", basket['ALARM CLOCK BAKELIKE RED'].sum())
# Out:
# ALARM CLOCK BAKELIKE GREEN :  340.0
# ALARM CLOCK BAKELIKE RED   :  316.0

# %%
Stock = pd.read_csv("Online-Retail-Dataset.csv", encoding = 'latin1')

# %%
basket2 = (Stock[Stock['Country'] == "Spain"].groupby(['Invoice', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0).set_index('Invoice'))
basket2.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   RED SPOT GIFT BAG LARGE  \
# Invoice
# 536944                                  0.0                       0.0
# 538095                                  0.0                       0.0
# 538525                                  0.0                       0.0
# 539351                                  0.0                       0.0
# 540469                                  0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# Invoice
# 536944                                    0.0                      0.0
# 538095                                    0.0                      0.0
# 538525                                    0.0                      0.0
# 539351                                    0.0                      0.0
# 540469                                    8.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 EGG HOUSE PAINTED WOOD  \
# Invoice
# 536944                          0.0                        0.0
# 538095                          0.0                        0.0
# 538525                          0.0                        0.0
# 539351                          0.0                        0.0
# 540469                          0.0                        0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# Invoice
# 536944                                   0.0                            0.0
# 538095                                   0.0                            0.0
# 538525                                   0.0                            0.0
# 539351                                   0.0                            0.0
# 540469                                   0.0                            0.0
#
# Description  20 DOLLY PEGS RETROSPOT  200 RED + WHITE BENDY STRAWS  ...  \
# Invoice                                                             ...
# 536944                           0.0                           0.0  ...
# 538095                           0.0                           0.0  ...
# 538525                           0.0                           0.0  ...
# 539351                           0.0                           0.0  ...
# 540469                           0.0                           0.0  ...
#
# Description  WRAP RED APPLES   WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# Invoice
# 536944                    0.0                     0.0                    0.0
# 538095                    0.0                     0.0                    0.0
# 538525                    0.0                     0.0                    0.0
# 539351                    0.0                     0.0                    0.0
# 540469                    0.0                     0.0                    0.0
#
# Description  WRAP, BILLBOARD FONTS DESIGN  YELLOW COAT RACK PARIS FASHION  \
# Invoice
# 536944                                0.0                             0.0
# 538095                                0.0                             1.0
# 538525                                0.0                             0.0
# 539351                                0.0                             0.0
# 540469                                0.0                             0.0
#
# Description  YELLOW FLOWERS FELT HANDBAG KIT  ZINC FOLKART SLEIGH BELLS  \
# Invoice
# 536944                                   0.0                        0.0
# 538095                                   0.0                        0.0
# 538525                                   0.0                        0.0
# 539351                                   0.0                        0.0
# 540469                                   4.0                        0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# Invoice
# 536944                               0.0                             0.0
# 538095                               0.0                             0.0
# 538525                               0.0                             0.0
# 539351                               0.0                             0.0
# 540469                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# Invoice
# 536944                                   0.0
# 538095                                   0.0
# 538525                                   0.0
# 539351                                   0.0
# 540469                                   0.0
#
# [5 rows x 1107 columns]

# %%
basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace = True, axis = 1)
frequent_itemsets2 = apriori(basket_sets2, min_support = 0.05, use_colnames = True)
rules2 = association_rules(frequent_itemsets2, metric = "lift", min_threshold = 1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x = "support", y = "confidence", size = "lift", data = rules2)
plt.show()

# %%
rules2[(rules2['lift'] >= 4) & (rules2['confidence'] >= 0.5)]
# Out:
#                                           antecedents  \
# 0                            (6 RIBBONS RUSTIC CHARM)
# 1                     (ASSORTED COLOUR BIRD ORNAMENT)
# 7                            (PLASTERS IN TIN SKULLS)
# 8                                (RED RETROSPOT TAPE)
# 10                  (PACK OF 72 RETROSPOT CAKE CASES)
# 11                    (ASSORTED COLOUR BIRD ORNAMENT)
# 12                    (ASSORTED COLOUR BIRD ORNAMENT)
# 13                           (PLASTERS IN TIN SKULLS)
# 14                              (SPACEBOY LUNCH BOX )
# 15                             (DOLLY GIRL LUNCH BOX)
# 16                  (GREEN REGENCY TEACUP AND SAUCER)
# 17                 (ROSES REGENCY TEACUP AND SAUCER )
# 18              (SET/5 RED RETROSPOT LID GLASS BOWLS)
# 20                          (LUNCH BAG RED RETROSPOT)
# 21                          (LUNCH BAG PINK POLKADOT)
# 22                   (PLASTERS IN TIN CIRCUS PARADE )
# 23                           (PLASTERS IN TIN SKULLS)
# 24                        (POPPY'S PLAYHOUSE KITCHEN)
# 25                       (POPPY'S PLAYHOUSE BEDROOM )
# 26                              (SPACEBOY LUNCH BOX )
# 27                         (RED RETROSPOT CAKE STAND)
# 30               (SET/10 PINK POLKADOT PARTY CANDLES)
# 31               (SET OF 6 GIRLS CELEBRATION CANDLES)
# 32  (PACK OF 72 RETROSPOT CAKE CASES, 6 RIBBONS RU...
# 33  (PACK OF 72 RETROSPOT CAKE CASES, ASSORTED COL...
# 34  (6 RIBBONS RUSTIC CHARM, ASSORTED COLOUR BIRD ...
# 35                  (PACK OF 72 RETROSPOT CAKE CASES)
# 37                    (ASSORTED COLOUR BIRD ORNAMENT)
#
#                                           consequents  antecedent support  \
# 0                     (ASSORTED COLOUR BIRD ORNAMENT)            0.142857
# 1                            (6 RIBBONS RUSTIC CHARM)            0.114286
# 7                            (6 RIBBONS RUSTIC CHARM)            0.095238
# 8                            (6 RIBBONS RUSTIC CHARM)            0.066667
# 10                    (ASSORTED COLOUR BIRD ORNAMENT)            0.104762
# 11                  (PACK OF 72 RETROSPOT CAKE CASES)            0.114286
# 12                           (PLASTERS IN TIN SKULLS)            0.114286
# 13                    (ASSORTED COLOUR BIRD ORNAMENT)            0.095238
# 14                             (DOLLY GIRL LUNCH BOX)            0.114286
# 15                              (SPACEBOY LUNCH BOX )            0.085714
# 16                 (ROSES REGENCY TEACUP AND SAUCER )            0.057143
# 17                  (GREEN REGENCY TEACUP AND SAUCER)            0.104762
# 18                         (JAM MAKING SET WITH JARS)            0.057143
# 20                          (LUNCH BAG PINK POLKADOT)            0.076190
# 21                          (LUNCH BAG RED RETROSPOT)            0.095238
# 22                           (PLASTERS IN TIN SKULLS)            0.066667
# 23                   (PLASTERS IN TIN CIRCUS PARADE )            0.095238
# 24                       (POPPY'S PLAYHOUSE BEDROOM )            0.066667
# 25                        (POPPY'S PLAYHOUSE KITCHEN)            0.076190
# 26                         (RED RETROSPOT CAKE STAND)            0.114286
# 27                              (SPACEBOY LUNCH BOX )            0.076190
# 30               (SET OF 6 GIRLS CELEBRATION CANDLES)            0.066667
# 31               (SET/10 PINK POLKADOT PARTY CANDLES)            0.066667
# 32                    (ASSORTED COLOUR BIRD ORNAMENT)            0.057143
# 33                           (6 RIBBONS RUSTIC CHARM)            0.057143
# 34                  (PACK OF 72 RETROSPOT CAKE CASES)            0.085714
# 35  (6 RIBBONS RUSTIC CHARM, ASSORTED COLOUR BIRD ...            0.104762
# 37  (PACK OF 72 RETROSPOT CAKE CASES, 6 RIBBONS RU...            0.114286
#
#     consequent support   support  confidence       lift  leverage  conviction  \
# 0             0.114286  0.085714    0.600000   5.250000  0.069388    2.214286
# 1             0.142857  0.085714    0.750000   5.250000  0.069388    3.428571
# 7             0.142857  0.057143    0.600000   4.200000  0.043537    2.142857
# 8             0.142857  0.057143    0.857143   6.000000  0.047619    6.000000
# 10            0.114286  0.057143    0.545455   4.772727  0.045170    1.948571
# 11            0.104762  0.057143    0.500000   4.772727  0.045170    1.790476
# 12            0.095238  0.057143    0.500000   5.250000  0.046259    1.809524
# 13            0.114286  0.057143    0.600000   5.250000  0.046259    2.214286
# 14            0.085714  0.057143    0.500000   5.833333  0.047347    1.828571
# 15            0.114286  0.057143    0.666667   5.833333  0.047347    2.657143
# 16            0.104762  0.057143    1.000000   9.545455  0.051156         inf
# 17            0.057143  0.057143    0.545455   9.545455  0.051156    2.074286
# 18            0.133333  0.057143    1.000000   7.500000  0.049524         inf
# 20            0.095238  0.057143    0.750000   7.875000  0.049887    3.619048
# 21            0.076190  0.057143    0.600000   7.875000  0.049887    2.309524
# 22            0.095238  0.057143    0.857143   9.000000  0.050794    6.333333
# 23            0.066667  0.057143    0.600000   9.000000  0.050794    2.333333
# 24            0.076190  0.066667    1.000000  13.125000  0.061587         inf
# 25            0.066667  0.066667    0.875000  13.125000  0.061587    7.466667
# 26            0.076190  0.057143    0.500000   6.562500  0.048435    1.847619
# 27            0.114286  0.057143    0.750000   6.562500  0.048435    3.542857
# 30            0.066667  0.057143    0.857143  12.857143  0.052698    6.533333
# 31            0.066667  0.057143    0.857143  12.857143  0.052698    6.533333
# 32            0.114286  0.057143    1.000000   8.750000  0.050612         inf
# 33            0.142857  0.057143    1.000000   7.000000  0.048980         inf
# 34            0.104762  0.057143    0.666667   6.363636  0.048163    2.685714
# 35            0.085714  0.057143    0.545455   6.363636  0.048163    2.011429
# 37            0.057143  0.057143    0.500000   8.750000  0.050612    1.885714
#
#     zhangs_metric
# 0        0.944444
# 1        0.913978
# 7        0.842105
# 8        0.892857
# 10       0.882979
# 11       0.892473
# 12       0.913978
# 13       0.894737
# 14       0.935484
# 15       0.906250
# 16       0.949495
# 17       1.000000
# 18       0.919192
# 20       0.945017
# 21       0.964912
# 22       0.952381
# 23       0.982456
# 24       0.989796
# 25       1.000000
# 26       0.956989
# 27       0.917526
# 30       0.988095
# 31       0.988095
# 32       0.939394
# 33       0.909091
# 34       0.921875
# 35       0.941489
# 37       1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pivot = rules2.pivot(index = 'consequents', columns = 'antecedents', values= 'lift')

sns.heatmap(pivot, annot = True, cbar = False)
plt.yticks(rotation = 0)
plt.xticks(rotation = 90)
plt.show()
